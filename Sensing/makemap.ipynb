# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('C:/Users/jdiro/Desktop/git/PathPlanning/Search_based_Planning/Search_2D/finalpath_slow.csv',
                delimiter = ',',
                names = ['x','y','theta'],
                skiprows=1)




fig = plt.figure(dpi=300)

x = [77,70,70,440,440,760,760,1060,1180]
y = [33,1024-280,1024-600,1024-600,1024-280,1024-600,1024-280,1024-600,1024-490]
colors = ['black','#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']

im = plt.imread('2510-2.jpg')
implot = plt.imshow(im)

plt.gca().invert_yaxis()
plt.scatter(x,y,color=colors)
for i in range(1,len(x)):
    plt.text(x[i]-20, y[i]+30, 'p'+str(i)+'\n('+str(x[i])+','+str(y[i])+')', fontsize=8, color = colors[i])

plt.scatter(1150,990,color = 'black')
for i in range(6):
    plt.plot([i*250+100+70,i*250+100-70],[990,990],color = 'blue')
for i in range(6):
    plt.plot([i*250+100+70,i*250+100-70],[970,970],color = 'grey')
    
plt.plot([130,200],[320,320],color = 'black')
plt.plot([1130,1200],[320,320],color = 'black')

plt.fill([30, 100, 100, 30], [920, 920, 880, 880], fill=False, hatch='//////', color='brown')
plt.fill([1400, 1470, 1470, 1400], [920, 920, 880, 880], fill=False, hatch='//////', color='brown')
plt.fill([500, 600, 600, 500], [190, 190, 210, 210], fill=False, hatch='//////', color='brown')
plt.text(630,190,'Ceiling Exhaust', fontsize=8)

plt.fill([150, 190, 190, 150], [870, 870, 850, 850], fill=False, hatch='//////', color='orange')
plt.fill([230, 270, 270, 230], [870, 870, 850, 850], fill=False, hatch='//////', color='orange')
plt.fill([150, 190, 190, 150], [570, 570, 550, 550], fill=False, hatch='//////', color='orange')
plt.fill([230, 270, 270, 230], [570, 570, 550, 550], fill=False, hatch='//////', color='orange')

plt.fill([490, 530, 530, 490], [760, 760, 740, 740], fill=False, hatch='//////', color='orange')
plt.fill([570, 610, 610, 570], [870, 870, 850, 850], fill=False, hatch='//////', color='orange')
plt.fill([490, 530, 530, 490], [570, 570, 550, 550], fill=False, hatch='//////', color='orange')
plt.fill([570, 610, 610, 570], [570, 570, 550, 550], fill=False, hatch='//////', color='orange')

plt.fill([810, 850, 850, 810], [870, 870, 850, 850], fill=False, hatch='//////', color='orange')
plt.fill([890, 930, 930, 890], [870, 870, 850, 850], fill=False, hatch='//////', color='orange')
plt.fill([810, 850, 850, 810], [570, 570, 550, 550], fill=False, hatch='//////', color='orange')
plt.fill([890, 930, 930, 890], [670, 670, 650, 650], fill=False, hatch='//////', color='orange')

plt.fill([1100, 1140, 1140, 1100], [350, 350, 330, 330], fill=False, hatch='//////', color='orange')

plt.fill([500, 600, 600, 500], [150, 150, 170, 170], fill=False, hatch='//////', color='orange')
plt.text(630,150,'Computer', fontsize=8)
    
plt.plot([500,600],[110,110],color = 'blue')
plt.text(630,100,'Window', fontsize=8)
plt.plot([500,600],[70,70],color = 'grey')
plt.text(630,60,'Local Diffuser', fontsize=8)
plt.plot([500,600],[30,30],color = 'black')
plt.text(630,20,'Central Diffuser', fontsize=8)
plt.plot([500,600],[30,30],color = 'black')


plt.text(1143,940, 'Window Fan', fontsize=8)
plt.xlabel('x (cm), U')
plt.ylabel('y (cm), V')
plt.text(1350,25,r'$\bigodot$ z,W',fontsize=8)
#plt.plot(df['y'],1024-df['x'])
plt.text(x[0]+33,y[0],'Start', fontsize=8)

plt.savefig('RoomMap.pdf', format='pdf')

# %%
print(plt.rcParams['axes.prop_cycle'].by_key()['color'])
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
