# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

fileName = './Raw/-200pwm_Spin_raw.xlsx'

# %%
data = pd.read_excel(fileName)
data.columns=(['timeglobal','timenow','rb1x','rb1y','rb1z','rb2x','rb2y','rb2z','rb3x','rb3y','rb3z','rb4x','rb4y','rb4z','rb5x','rb5y','rb5z','u1','u2','u3','u4'])


#print(data)

# %%
plt.plot(data['rb5x'][:50]-data['rb5x'][2],data['rb5y'][:50]-data['rb5y'][2])

# %%
dx=[]
for i in range(len(data['timeglobal'])-1):
    dx.append(data['timeglobal'][i+1]-data['timeglobal'][i])
    
plt.plot(dx)

# %%
print(data['timeglobal'][:60])
# Out:
# 0      0.205963
# 1      0.413531
# 2      0.621393
# 3      0.828921
# 4      1.033644
# 5      1.241039
# 6      1.445732
# 7      1.649703
# 8      1.857014
# 9      2.063227
# 10     2.268434
# 11     2.471392
# 12     2.678876
# 13     2.884639
# 14     3.089869
# 15     3.297166
# 16     3.506520
# 17     3.711702
# 18     3.918576
# 19     4.127972
# 20     4.333490
# 21     4.540980
# 22     4.747776
# 23     4.951853
# 24     5.155539
# 25     5.358384
# 26     5.561806
# 27     5.764795
# 28     5.967379
# 29     6.170731
# 30     6.378894
# 31     6.583849
# 32     6.789671
# 33     6.998535
# 34     7.203941
# 35     7.406622
# 36     7.609711
# 37     7.813388
# 38     8.021368
# 39     8.232635
# 40     8.437442
# 41     8.646880
# 42     8.852099
# 43     9.054757
# 44     9.257544
# 45     9.460591
# 46     9.668221
# 47     9.874471
# 48    10.080182
# 49    10.085127
# 50    10.090982
# 51    10.100190
# 52    10.119706
# 53    10.130751
# 54    10.134649
# 55    10.142043
# 56    10.150150
# 57    10.160178
# 58    10.169992
# 59    10.180186
# Name: timeglobal, dtype: float64
